# %%
import numpy as np
import sys
import heapq
np.set_printoptions(threshold = sys.maxsize)
speed = 30
ANGLE_STEP = 10
CAR_START = (50,0)
MIN_DISTANCE_LINE = 3500
DESTINATION = [75,30]
MIN_MOVE_DISTANCE = 10

# %%
def get_points_from_distances(distance):
    points = []
    cur_angle = -90
    i=0
    while(cur_angle<=90):
        if(distance[i]> 0):
            x = int(distance[i]*np.sin(cur_angle*np.pi/180.0)+CAR_START[0])
            y = int(distance[i]*np.cos(cur_angle*np.pi/180.0))
            if(x>-1 and x<100 and y>-1 and y<100):        
                points.append((int(x),int(y)))
        i+=1
        cur_angle+=ANGLE_STEP
    return points
def get_map_from_distances(distance):
    points = get_points_from_distances(distance)
    map = np.zeros((100,100))
    map[50][0] = 3
    for i in points:
        if(i[0] < 100 and i[1]<100):
            map[i[0]][i[1]] = 1
    i=0
    while(i<len(points) - 1):
        point1 = points[i]
        point2 = points[i+1]
        xdif = np.abs(point1[0]-point2[0])
        ydif = np.abs(point1[1]-point2[1])
        xdif_abs = 1 if point2[0]-point1[0]>0 else -1
        ydif_abs = 1 if point2[1]-point1[1]>0 else -1
        if(xdif*xdif+ydif*ydif > MIN_DISTANCE_LINE):
            i+=1
            continue
        scale = float(ydif/xdif)
        cur_point = [point1[0],point1[1]]
        while(cur_point[0] != point2[0] or cur_point[1] != point2[1]):
            xdif = np.abs(cur_point[0]-point2[0])
            ydif = np.abs(cur_point[1]-point2[1])
            if(xdif == 0):
                for yval in range(cur_point[1],point2[1]+ydif_abs,ydif_abs):
                    map[cur_point[0]][yval] = 1
                cur_point = point2
                continue
            if(ydif == 0):
                for xval in range(cur_point[0],point2[0]+xdif_abs,xdif_abs):
                    map[xval][cur_point[1]] = 1
                cur_point = point2
                continue
            

    
            scale = float(ydif/xdif)
            
            if(scale>1):
                cur_point[0]+=xdif_abs
                map[cur_point[0]][cur_point[1]] = 1
                scale_int = int(scale)
                for scale_val in range(scale_int):
                    cur_point[1]+=ydif_abs
                    map[cur_point[0]][cur_point[1]] = 1
            elif(scale<1):
                cur_point[1]+=ydif_abs
                map[cur_point[0]][cur_point[1]] = 1
                scale_int = int(1/scale)
                for scale_val in range(scale_int):
                    cur_point[0]+=xdif_abs
                    map[cur_point[0]][cur_point[1]] = 1
            else:
                map[cur_point[0]][cur_point[1]] = 1
                map[cur_point[0]+xdif_abs][cur_point[1]] = 1
                map[cur_point[0]][cur_point[1]+ydif_abs] = 1
                cur_point=[cur_point[0]+xdif_abs,cur_point[1]+ydif_abs]



        i+=1
    return map

# %%
def heuristic(a, b):
    return np.sqrt((b[0] - a[0]) ** 2 + (b[1] - a[1]) ** 2)

def astar(array, start, goal):

    neighbors = [(0,MIN_MOVE_DISTANCE),(0,-MIN_MOVE_DISTANCE),(MIN_MOVE_DISTANCE,0),(-MIN_MOVE_DISTANCE,0)]

    close_set = set()

    came_from = {}

    gscore = {start:0}

    fscore = {start:heuristic(start, goal)}
    oheap = []

    heapq.heappush(oheap, (fscore[start], start))
    while oheap:

        current = heapq.heappop(oheap)[1]
        if current == goal:

            data = []

            while current in came_from:

                data.append(current)

                current = came_from[current]
            data.reverse()
            return data
        close_set.add(current)
        for i, j in neighbors:

            neighbor = current[0] + i, current[1] + j            
            
            tentative_g_score = gscore[current] + heuristic(current, neighbor)

            if 0 <= neighbor[0] < array.shape[0]:

                if 0 <= neighbor[1] < array.shape[1]:                

                    if array[neighbor[0]][neighbor[1]] == 1:

                        continue

                else:
                    
                    # array bound y walls

                    continue

            else:

                # array bound x walls

                continue
 

            if neighbor in close_set and tentative_g_score >= gscore.get(neighbor, 0):

                continue
 

            if  tentative_g_score < gscore.get(neighbor, 0) or neighbor not in [i[1]for i in oheap]:

                came_from[neighbor] = current

                gscore[neighbor] = tentative_g_score

                fscore[neighbor] = tentative_g_score + heuristic(neighbor, goal)

                heapq.heappush(oheap, (fscore[neighbor], neighbor))

# %%
distances = [100,100,100,100,100,100,10,10,10,10,10,10,100,100,100,100,100,100,100]
m = get_map_from_distances(distances)
m = np.array(m, dtype = int)
val = astar(m,CAR_START,(DESTINATION[0],DESTINATION[1]))
print(val)
for i in val:
    m[i[0]][i[1]] = 2
for x in m:
    for y in x:
        print(y,end='',sep='')
    print()
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [48], line 6
#       4 val = astar(m,CAR_START,(DESTINATION[0],DESTINATION[1]))
#       5 print(val)
# ----> 6 for i in val:
#       7     m[i[0]][i[1]] = 2
#       8 for x in m:
#
# TypeError: 'NoneType' object is not iterable

# %%
DESTINATION = [150,150]
CAR_START= [50,0]
def local_destination():
    #has DESTINATION which is with respect to CAR_START 
    # need to get point in 100,100 which is equivalent
    local = [DESTINATION[0]+CAR_START[0],DESTINATION[1]+CAR_START[1]]
    if(local[0]<100 and local[1]<100 and local[0]>=0 and local[1]>=0):
        return local
    if(local[1]-CAR_START[1] == 0):
        if(local[0]-CAR_START[0]>0):
            return [99,CAR_START[1]]
        else:
            return [0,CAR_START[1]]
    if(local[0]-CAR_START[0]==0):
        return [50,99]
    
    slope = (local[1]-CAR_START[1])/(local[0]-CAR_START[0])
    y_for_x_100 = int(slope*49)
    x_for_y_100 = int(99.0/slope+50)
    print(slope)
    if(x_for_y_100 <100 and x_for_y_100 >=0):
        return [x_for_y_100,99]
    elif(y_for_x_100>0):
        return [99,y_for_x_100]
    else:
        return [0,-y_for_x_100]
    return local

# %%
print(local_destination())
# Out:
# 1.0
# [99, 49]

# %%
import smtplib, ssl

port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "dhruvz123z@gmail.com"  # Enter your address
receiver_email = "dhruvr4@illinois.edu"  # Enter receiver address
password = input("Type your password and press enter: ")
message = """\
Subject: Hi there

This message is sent from Python."""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In [8], line 15
#      13 context = ssl.create_default_context()
#      14 with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
# ---> 15     server.login(sender_email, password)
#      16     server.sendmail(sender_email, receiver_email, message)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/smtplib.py:745, in SMTP.login(self, user, password, initial_response_ok)
#     742         last_exception = e
#     744 # We could not login successfully.  Return result of last attempt.
# --> 745 raise last_exception
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/smtplib.py:734, in SMTP.login(self, user, password, initial_response_ok)
#     732 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     733 try:
# --> 734     (code, resp) = self.auth(
#     735         authmethod, getattr(self, method_name),
#     736         initial_response_ok=initial_response_ok)
#     737     # 235 == 'Authentication successful'
#     738     # 503 == 'Error: already authenticated'
#     739     if code in (235, 503):
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/smtplib.py:657, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     655 if code in (235, 503):
#     656     return (code, resp)
# --> 657 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials q23-20020a02b057000000b0038a3b8aaf11sm3526839jah.37 - gsmtp')
